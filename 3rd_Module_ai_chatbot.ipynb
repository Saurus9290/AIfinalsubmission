# %%
# !pip install openai
import pandas as pd
import numpy as np
import json
import openai
from sklearn.metrics.pairwise import cosine_similarity
import os
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 9.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# !pip install openai: This line is installing the openai library using the pip package manager. The exclamation mark before pip indicates that this code is meant to be run in a command-line or terminal environment.
#
# import pandas as pd: This line imports the pandas library and assigns it the alias pd. The pandas library is commonly used for data manipulation and analysis.
#
# import numpy as np: This line imports the numpy library and assigns it the alias np. numpy is a library for numerical computing in Python and provides powerful array and matrix operations.
#
# import json: This line imports the built-in json module, which provides functions for working with JSON (JavaScript Object Notation) data.
#
# import openai: This line imports the openai library. It seems that you are using a library called openai, which is not a standard Python library. This library may have specific functions and features related to artificial intelligence or machine learning tasks.
#
# from sklearn.metrics.pairwise import cosine_similarity: This line imports the cosine_similarity function from the sklearn.metrics.pairwise module. cosine_similarity is a function used to compute the cosine similarity between two vectors or sets of vectors.
#
# import os: This line imports the built-in os module, which provides functions for interacting with the operating system, such as managing files and directories.
#
# It's important to note that the code you provided does not include any actual usage of the imported libraries and modules. Without further code, it's difficult to determine the purpose or functionality of the script.

# %%
size = 1000
jump = 5
json_link = 'https://raw.githubusercontent.com/GJBroughton/Star_Trek_Scripts/master/data/all_scripts_raw.json'
content= pd.read_json(json_link)
words = content['DS9']['episode 0']
tokens = words.split()
# print(tokens)
chunks = [tokens[i:i+size] for i in range(0, len(tokens), size-jump)]
print(chunks)
df = pd.DataFrame(columns=['chunk', 'gpt_raw', 'embedding'])
# Out:
# [['The', 'Deep', 'Space', 'Nine', 'Transcripts', '-', 'Emissary', 'Emissary', 'Stardate:', '46379.1', 'Original', 'Airdate:', '3', 'Jan,', '1993', 'On', 'Stardate', '43997,', 'Captain', 'Jean-Luc', 'Picard', 'of', 'the', 'Federation', 'Starship', 'Enterprise', 'was', 'kidnapped', 'for', 'six', 'days', 'by', 'an', 'invading', 'force', 'known', 'as', 'the', 'Borg.', 'Surgically', 'altered,', 'he', 'was', 'forced', 'to', 'lead', 'an', 'assault', 'on', 'Starfleet', 'at', 'Wolf', '359.', '[Saratoga', '-', 'Bridge]', 'LOCUTUS', '[on', 'viewscreen]:', 'Resistance', 'is', 'futile.', 'You', 'will', 'disarm', 'your', 'weapons', 'and', 'escort', 'us', 'to', 'sector', 'zero', 'zero', 'one.', 'If', 'you', 'attempt', 'to', 'intervene,', 'we', 'will', 'destroy', 'you.', 'CAPTAIN:', '(a', 'Vulcan)', 'Red', 'alert.', 'Load', 'all', 'torpedo', 'bays.', 'Ready', 'phasers.', 'Move', 'us', 'to', 'position', 'alpha,', 'Ensign.', '(The', 'space', 'battle', 'begins)', 'OPS', 'OFFICER:', '(woman)', "They've"
# ...

# %% [markdown]
# size = 1000: This line assigns the value 1000 to the variable size. It seems to be used as a parameter to determine the chunk size for dividing the tokens later in the code.
#
# jump = 5: This line assigns the value 5 to the variable jump. It appears to be used as a parameter to determine the jump size between chunks when dividing the tokens.
#
# json_link = 'https://raw.githubusercontent.com/GJBroughton/Star_Trek_Scripts/master/data/all_scripts_raw.json': This line assigns a URL string to the variable json_link. The URL points to a JSON file containing Star Trek scripts.
#
# content = pd.read_json(json_link): This line reads the JSON file from the provided URL using pd.read_json() function from the pandas library. The content of the JSON file is loaded into the content variable.
#
# words = content['DS9']['episode 0']: This line retrieves the value from the content variable. It looks like the JSON file has a structure with a key 'DS9', and under that key, there is another key 'episode 0'. The value corresponding to this key is assigned to the words variable.
#
# tokens = words.split(): This line splits the string in words into a list of tokens using the split() method. By default, the split() method splits the string on whitespace, so each word will become a separate token. The resulting tokens are assigned to the tokens variable.
#
# chunks = [tokens[i:i+size] for i in range(0, len(tokens), size-jump)]: This line creates a list of chunks by dividing the tokens list into smaller sublists. Each sublist has a length of size (1000 in this case), and the jump value (5) determines the step size for creating the sublists. This creates overlapping chunks. The resulting list of chunks is assigned to the chunks variable.
#
# print(chunks): This line prints the chunks list, which contains the divided tokens.
#
# df = pd.DataFrame(columns=['chunk', 'gpt_raw', 'embedding']): This line creates an empty DataFrame using the pd.DataFrame() function from the pandas library. The DataFrame has three columns: 'chunk', 'gpt_raw', and 'embedding'. The df variable is assigned this empty DataFrame.
#
# It seems like this code is processing Star Trek scripts, dividing them into smaller chunks of tokens, and creating an empty DataFrame for storing the chunks and related data.

# %%
openai.api_key = input()
# Out:
# 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

# %%
for i in chunks:
    f = openai.Embedding.create(
        model="text-embedding-ada-002",
        input=" ".join(i),
    )
    print(i)
    df.loc[len(df.index)] = (i, f, np.array(f['data'][0]['embedding']))
# Out:
# ['The', 'Deep', 'Space', 'Nine', 'Transcripts', '-', 'Emissary', 'Emissary', 'Stardate:', '46379.1', 'Original', 'Airdate:', '3', 'Jan,', '1993', 'On', 'Stardate', '43997,', 'Captain', 'Jean-Luc', 'Picard', 'of', 'the', 'Federation', 'Starship', 'Enterprise', 'was', 'kidnapped', 'for', 'six', 'days', 'by', 'an', 'invading', 'force', 'known', 'as', 'the', 'Borg.', 'Surgically', 'altered,', 'he', 'was', 'forced', 'to', 'lead', 'an', 'assault', 'on', 'Starfleet', 'at', 'Wolf', '359.', '[Saratoga', '-', 'Bridge]', 'LOCUTUS', '[on', 'viewscreen]:', 'Resistance', 'is', 'futile.', 'You', 'will', 'disarm', 'your', 'weapons', 'and', 'escort', 'us', 'to', 'sector', 'zero', 'zero', 'one.', 'If', 'you', 'attempt', 'to', 'intervene,', 'we', 'will', 'destroy', 'you.', 'CAPTAIN:', '(a', 'Vulcan)', 'Red', 'alert.', 'Load', 'all', 'torpedo', 'bays.', 'Ready', 'phasers.', 'Move', 'us', 'to', 'position', 'alpha,', 'Ensign.', '(The', 'space', 'battle', 'begins)', 'OPS', 'OFFICER:', '(woman)', "They've",
# ...

# %% [markdown]
# for i in chunks:: This line starts a loop that iterates over each element (i) in the chunks list.
#
# f = openai.Embedding.create(model="text-embedding-ada-002", input=" ".join(i)): This line creates an embedding using the OpenAI openai.Embedding.create() method. It utilizes the "text-embedding-ada-002" model to generate the embedding. The input parameter is set to the joined tokens of the current chunk (i) by using " ".join(i). This converts the list of tokens into a string where each token is separated by a space. The resulting embedding is assigned to the variable f.
#
# print(i): This line prints the current chunk (i).
#
# df.loc[len(df.index)] = (i, f, np.array(f['data'][0]['embedding'])): This line adds a new row to the DataFrame df. df.loc[len(df.index)] selects the last index of the DataFrame and assigns values to the columns specified in columns=['chunk', 'gpt_raw', 'embedding']. The values being assigned are i (the current chunk), f (the embedding object returned by OpenAI), and np.array(f['data'][0]['embedding']) (the embedding itself, extracted from the embedding object and converted into a NumPy array).
#
# To summarize, this code loops through the chunks list, creates an embedding for each chunk using the specified OpenAI model, and then prints the chunk. It also adds the chunk, the embedding object, and the embedding itself as a row to the DataFrame df.

# %%
df.tail()
# Out:
#                                                chunk  \
# 5  [compensate, for, the, spatial, discontinuitie...
# 6  [I, do, not, understand, the, threat, I, bring...
# 7  [me, here., [Observation, lounge], PICARD:, It...
# 8  [can't, leave, her, here., Oh,, no!, SISKO:, I...
# 9  [with, Odo), So,, where, can, someone, practic...
#
#                                              gpt_raw  \
# 5  {'object': 'list', 'data': [{'object': 'embedd...
# 6  {'object': 'list', 'data': [{'object': 'embedd...
# 7  {'object': 'list', 'data': [{'object': 'embedd...
# 8  {'object': 'list', 'data': [{'object': 'embedd...
# 9  {'object': 'list', 'data': [{'object': 'embedd...
#
#                                            embedding
# 5  [0.0037201163358986378, 0.007736712694168091, ...
# 6  [0.016182024031877518, -0.012033696286380291, ...
# 7  [0.0008436700445599854, -0.011623699218034744,...
# 8  [0.003335648914799094, -0.012816288508474827, ...
# 9  [0.01565542444586754, -0.02538183145225048, 0....

# %%
query = "Have you seen Jennifer?"
f = openai.Embedding.create(
    model="text-embedding-ada-002",
    input=query
)

# %% [markdown]
# The code you provided is using OpenAI's openai.Embedding.create() method to generate an embedding for a given query. Let's break down the code step by step:
#
# query = "Have you seen Jennifer?": This line assigns the string "Have you seen Jennifer?" to the variable query. This is the text for which you want to generate an embedding.
#
# f = openai.Embedding.create(model="text-embedding-ada-002", input=query): This line creates an embedding using the OpenAI openai.Embedding.create() method. It specifies the model to be used as "text-embedding-ada-002" and the input as the query variable. This means that you want to generate an embedding for the given query using the specified model.
#
# The resulting embedding will be stored in the variable f.
#
# Please note that to use the OpenAI API, you need to have the necessary credentials and appropriate API access. Additionally, the code you provided does not show how the embedding is used or further processed after it is generated.

# %%
similarity = []
query_embedding = np.array(f['data'][0]['embedding'])

for arr in df['embedding'].values:
    similarity.extend(cosine_similarity(query_embedding.reshape(1, -1), arr.reshape(1, -1)))
context_chunk = chunks[np.argmax(similarity)]

query_to_send = "CONTEXT: " + " ".join(context_chunk) + "\n\n" + query

# %% [markdown]
# The code you provided computes the cosine similarity between a query embedding and the embeddings stored in the DataFrame df

# %%
response = openai.Completion.create(
  model="text-davinci-002",
  prompt= query_to_send,
  max_tokens=100,
  temperature=0
)

# %% [markdown]
# The code you provided uses OpenAI's openai.Completion.create() method to generate a text completion based on a given prompt. Let's break down the code:
#
# response = openai.Completion.create(model="text-davinci-002", prompt=query_to_send, max_tokens=100, temperature=0): This line creates a completion using the OpenAI openai.Completion.create() method. It specifies the model to be used as "text-davinci-002".
# model="text-davinci-002": This parameter specifies the model to use for generating the completion. In this case, the "text-davinci-002" model is being used.
#
# prompt=query_to_send: This parameter specifies the prompt or input text to generate the completion. The variable query_to_send contains the prompt string created in the previous code block.
#
# max_tokens=100: This parameter specifies the maximum number of tokens in the generated completion. The value of 100 limits the response to 100 tokens.
#
# temperature=0: This parameter controls the randomness of the generated completion. A temperature of 0 indicates that the completion will be deterministic and focused.

# %%
print(query_to_send)
# Out:
# CONTEXT: I do not understand the threat I bring to you, but I am not your enemy. Allow me to prove it. [Bajor Monastery] OPAKA: Prove it? SISKO: It can be argued that a human is ultimately the sum of his experiences. [Fishing pond] JAKE: Experiences? What is this? SISKO: Memories. Events from my past, like this one. JAKE: Past? SISKO: Things that happened before now. You have absolutely no idea what I'm talking about. JAKE: What comes before now is no different than what is now, or what is to come. It is one's existence. SISKO: Then, for you, there is no linear time. [Beach] JENNIFER: Linear time. what is this? SISKO: My species lives in one point in time. And once we move beyond that point, it becomes the past. The future, all that is still to come, does not exist yet for us. JENNIFER: Does not exist yet? SISKO: That is the nature of linear existence. And if you examine it more closely, you will see that you do not need to fear me. [Ops] (A big forcefield tries to go up around the s
# ...

# %%
print(response['choices'][0]['text'])
# Out:
#  SISKO:
#
# No, sir. PICARD:
#
# I've been looking for her all morning. SISKO:
#
# I'm sure she'll turn up, sir. PICARD:
#
# I hope so. She's a very special person. SISKO:
#
# Yes, sir. PICARD:
#
# I'm glad you two are friends. SISKO:
#
# Yes, sir. PICARD:
#
# I'm
